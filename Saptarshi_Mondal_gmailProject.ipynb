# %% [markdown]
# <a href="https://colab.research.google.com/github/saptarshimondal1305/Task-2-GmailAPI/blob/main/Saptarshi_Mondal_gmailProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client

# %%
import imaplib
import email
from email.header import decode_header

# Replace 'your_email@gmail.com' and 'your_password' with your Gmail credentials
email_address = 'your_email@gmail.com'
password = 'your_password'


mail = imaplib.IMAP4_SSL('imap.gmail.com')


mail.login(email_address, password)


mail.select('inbox')


status, messages = mail.search(None, 'ALL')
email_ids = messages[0].split()


for msg_id in email_ids[-200:]:
    _, msg_data = mail.fetch(msg_id, '(RFC822)')
    raw_email = msg_data[0][1]
    msg = email.message_from_bytes(raw_email)


    sender, encoding = decode_header(msg.get("From"))[0]
    subject, encoding = decode_header(msg.get("Subject"))[0]

    if isinstance(sender, bytes):
        sender = sender.decode(encoding or 'utf-8')
    if isinstance(subject, bytes):
        subject = subject.decode(encoding or 'utf-8')

    print(f'Sender: {sender}, Subject: {subject}')


mail.logout()
# Out:
# Sender: MFTP <mftp.noticeboard@gmail.com>, Subject: #1666 | PLACEMENT | CV Submission | Tata Steel
# Sender: MFTP <mftp.noticeboard@gmail.com>, Subject: #1670 | PLACEMENT | CV Submission | BHARAT ELECTRONICS LIMITED
# Sender: MFTP <mftp.noticeboard@gmail.com>, Subject: #1669 | PLACEMENT | Urgent | CDC Placement process (Second Phase)
# Sender: "Public Relations Chairman, TSG | Irsh Vijayvargia" <prctsg@iitkgp.ac.in>, Subject: Kshitij 2024 - 19th to 21st Jan | Technology Students' Gymkhana
# Sender: Level SuperMind <hey@level.game>, Subject: your plan is confirmed ✅
# Sender: Glassdoor Jobs <noreply@glassdoor.com>, Subject: Engineers for Software Testing at Principle Circle Innovations LLP
#  and 17 more jobs in Bengaluru for you. Apply Now.
# Sender: "Adobe Acrobat" <mail@mail.adobe.com>, Subject: It's time to clear that pile of paper
# Sender: Level SuperMind <hey@level.game>, Subject: 🥲 I will be FIRED for this Saptarshi
# ...
